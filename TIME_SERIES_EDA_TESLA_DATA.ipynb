# %% [markdown]
# # TIME SERIES DATA EDA ON STOCKS DATA

# %%
#importing relevant libraries
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime
import yfinance as yf

# %%
tsla_data = yf.download('TSLA')
print(tsla_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-01-29  185.630005  191.479996  183.669998  190.929993  190.929993
# 2024-01-30  195.330002  196.360001  190.610001  191.589996  191.589996
# 2024-01-31  187.000000  193.970001  185.850006  187.289993  187.289993
# 2024-02-01  188.500000  189.880005  184.279999  188.860001  188.860001
# 2024-02-02  185.039993  188.690002  182.000000  187.910004  187.910004
#
#                Volume
# Date
# ...

# %%
type(tsla_data)
# Out:
# pandas.core.frame.DataFrame

# %%
tsla_data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
tsla_data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-29  185.630005  191.479996  183.669998  190.929993  190.929993
# 2024-01-30  195.330002  196.360001  190.610001  191.589996  191.589996
# 2024-01-31  187.000000  193.970001  185.850006  187.289993  187.289993
# 2024-02-01  188.500000  189.880005  184.279999  188.860001  188.860001
# 2024-02-02  185.039993  188.690002  182.000000  187.910004  187.910004
#
#                Volume
# Date
# 2024-01-29  125013100
# 2024-01-30  109982300
# 2024-01-31  103221400
# 2024-02-01   91843300
# 2024-02-02  110505100

# %%
tsla_data.plot(figsize =(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].plot(figsize =(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].plot(xlim = ['2020-01-01','2020-09-01'] , figsize =(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].plot(xlim = ['2020-01-01','2020-09-01'] ,ylim = [0,900] , figsize =(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].plot(xlim = ['2020-01-01','2020-09-01'] ,ylim = [0,900] , figsize =(12,4), c = 'red')
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].plot(xlim = ['2020-01-01','2020-09-01'] ,ylim = [0,900] , figsize =(12,4),ls = '--', c = 'red')
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-01-22', '2024-01-23', '2024-01-24', '2024-01-25',
#                '2024-01-26', '2024-01-29', '2024-01-30', '2024-01-31',
#                '2024-02-01', '2024-02-02'],
#               dtype='datetime64[ns]', name='Date', length=3423, freq=None)

# %%
index = tsla_data.loc['2020-01-01' : '2020-09-01'].index
share_open = tsla_data.loc['2020-01-01' : '2020-09-01']['Open']

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2020-08-19', '2020-08-20', '2020-08-21', '2020-08-24',
#                '2020-08-25', '2020-08-26', '2020-08-27', '2020-08-28',
#                '2020-08-31', '2020-09-01'],
#               dtype='datetime64[ns]', name='Date', length=169, freq=None)

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2020-08-26    137.333328
# 2020-08-27    145.363998
# 2020-08-28    153.007996
# 2020-08-31    148.203339
# 2020-09-01    167.380005
# Name: Open, Length: 169, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
figure , axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()   #preventing overlapping
axis.plot(index,share_open)

# %%
# datetime index
tsla_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3423 entries, 2010-06-29 to 2024-02-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3423 non-null   float64
#  1   High       3423 non-null   float64
#  2   Low        3423 non-null   float64
#  3   Close      3423 non-null   float64
#  4   Adj Close  3423 non-null   float64
#  5   Volume     3423 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 316.2 KB

# %%
df_tesla = tsla_data.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3423 entries, 0 to 3422
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3423 non-null   datetime64[ns]
#  1   Open       3423 non-null   float64
#  2   High       3423 non-null   float64
#  3   Low        3423 non-null   float64
#  4   Close      3423 non-null   float64
#  5   Adj Close  3423 non-null   float64
#  6   Volume     3423 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 187.3 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 3418   2024-01-29
# 3419   2024-01-30
# 3420   2024-01-31
# 3421   2024-02-01
# 3422   2024-02-02
# Name: Date, Length: 3423, dtype: datetime64[ns]

# %%
df_tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3418 2024-01-29  185.630005  191.479996  183.669998  190.929993  190.929993
# 3419 2024-01-30  195.330002  196.360001  190.610001  191.589996  191.589996
# 3420 2024-01-31  187.000000  193.970001  185.850006  187.289993  187.289993
# 3421 2024-02-01  188.500000  189.880005  184.279999  188.860001  188.860001
# 3422 2024-02-02  185.039993  188.690002  182.000000  187.910004  187.910004
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
df_tesla = df_tesla.set_index('Date', drop= True)

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-01-29  185.630005  191.479996  183.669998  190.929993  190.929993
# 2024-01-30  195.330002  196.360001  190.610001  191.589996  191.589996
# 2024-01-31  187.000000  193.970001  185.850006  187.289993  187.289993
# 2024-02-01  188.500000  189.880005  184.279999  188.860001  188.860001
# 2024-02-02  185.039993  188.690002  182.000000  187.910004  187.910004
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
# datetime
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 2, 5, 19, 30, 8, 962256)

# %%
date = datetime(2020,9,22)

# %%
date.date()
# Out:
# datetime.date(2020, 9, 22)

# %%
date.day
# Out:
# 22

# %%
date.weekday()
# Out:
# 1

# %%
date.year
# Out:
# 2020

# %%
date.month
# Out:
# 9

# %%
# time resampling
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
df_tesla.resample(rule = 'A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
df_tesla.resample(rule = 'A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
# year and frequency
df_tesla.resample(rule = 'A').max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# quarterly frequency
df_tesla.resample(rule = 'QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
df_tesla.resample(rule = 'QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#buisness end frequency
df_tesla.resample(rule = 'BA').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-30    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-30   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-29   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
df_tesla['Open'].resample(rule = 'BA').mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule = 'M').mean().plot(kind = 'bar', figsize = (20,10))
# Out:
# <Axes: xlabel='Date'>

# %%
#rolling
df_tesla['Open'].rolling(11).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13         NaN
# 2010-07-14    1.310242
# 2010-07-15    1.315939
# 2010-07-16    1.285091
# 2010-07-19    1.263091
# 2010-07-20    1.256121
# 2010-07-21    1.260121
# 2010-07-22    1.284970
# 2010-07-23    1.315576
# 2010-07-26    1.339333
# 2010-07-27    1.357273
# Name: Open, dtype: float64

# %%
df_tesla['Open: 30 days rolling'] = df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
df_tesla[['Open','Open: 30 days rolling']].plot(figsize = (12,5))
# Out:
# <Axes: xlabel='Date'>
